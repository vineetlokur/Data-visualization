# %%
import pandas as pd

# %%
nba = pd.read_csv("C:\\Users\\HP\\Downloads\\50-contacts.csv")

# %%
nba.head()
nba.head()
# Out:
#   first_name last_name            company_name               address  \
# 0      James      Butt       Benton, John B Jr    6649 N Blue Gum St
# 1  Josephine   Darakjy   Chanay, Jeffrey A Esq   4 B Blue Ridge Blvd
# 2        Art    Venere     Chemel, James L Cpa  8 W Cerritos Ave #54
# 3      Lenna  Paprocki  Feltz Printing Service           639 Main St
# 4    Donette    Foller     Printing Dimensions          34 Center St
#
#           city      county state    zip        phone1         phone  \
# 0  New Orleans     Orleans    LA  70116  504-621-8927  504-845-1427
# 1     Brighton  Livingston    MI  48116  810-292-9388  810-374-9840
# 2   Bridgeport  Gloucester    NJ   8014  856-636-8749  856-264-4130
# 3    Anchorage   Anchorage    AK  99501  907-385-4412  907-921-2010
# 4     Hamilton      Butler    OH  45011  513-570-1893  513-549-4561
#
#                            email
# 0                jbutt@gmail.com
# 1  josephine_darakjy@darakjy.org
# 2                 art@venere.org
# ...

# %%
nba.values
# Out:
# array([['James', 'Butt', 'Benton, John B Jr', '6649 N Blue Gum St',
#         'New Orleans', 'Orleans', 'LA', 70116, '504-621-8927',
#         '504-845-1427', 'jbutt@gmail.com'],
#        ['Josephine', 'Darakjy', 'Chanay, Jeffrey A Esq',
#         '4 B Blue Ridge Blvd', 'Brighton', 'Livingston', 'MI', 48116,
#         '810-292-9388', '810-374-9840', 'josephine_darakjy@darakjy.org'],
#        ['Art', 'Venere', 'Chemel, James L Cpa', '8 W Cerritos Ave #54',
#         'Bridgeport', 'Gloucester', 'NJ', 8014, '856-636-8749',
#         '856-264-4130', 'art@venere.org'],
#        ['Lenna', 'Paprocki', 'Feltz Printing Service', '639 Main St',
#         'Anchorage', 'Anchorage', 'AK', 99501, '907-385-4412',
#         '907-921-2010', 'lpaprocki@hotmail.com'],
#        ['Donette', 'Foller', 'Printing Dimensions', '34 Center St',
#         'Hamilton', 'Butler', 'OH', 45011, '513-570-1893',
#         '513-549-4561', 'donette.foller@cox.net'],
# ...

# %%
nba.shape
# Out:
# (50, 11)

# %%
nba.dtypes.values
# Out:
# array([dtype('O'), dtype('O'), dtype('O'), dtype('O'), dtype('O'),
#        dtype('O'), dtype('O'), dtype('int64'), dtype('O'), dtype('O'),
#        dtype('O')], dtype=object)

# %%
nba.axes
# Out:
# [RangeIndex(start=0, stop=50, step=1),
#  Index(['first_name', 'last_name', 'company_name', 'address', 'city', 'county',
#         'state', 'zip', 'phone1', 'phone', 'email'],
#        dtype='object')]

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   first_name    50 non-null     object
#  1   last_name     50 non-null     object
#  2   company_name  50 non-null     object
#  3   address       50 non-null     object
#  4   city          50 non-null     object
#  5   county        50 non-null     object
#  6   state         50 non-null     object
#  7   zip           50 non-null     int64
#  8   phone1        50 non-null     object
#  9   phone         50 non-null     object
#  10  email         50 non-null     object
# dtypes: int64(1), object(10)
# memory usage: 4.4+ KB

# %%
nba.sum(axis=0)
# Out:
# first_name      JamesJosephineArtLennaDonetteSimonaMitsueLeota...
# last_name       ButtDarakjyVenerePaprockiFollerMorascaTollnerD...
# company_name    Benton, John B JrChanay, Jeffrey A EsqChemel, ...
# address         6649 N Blue Gum St4 B Blue Ridge Blvd8 W Cerri...
# city            New OrleansBrightonBridgeportAnchorageHamilton...
# county          OrleansLivingstonGloucesterAnchorageButlerAshl...
# state           LAMINJAKOHOHILCASDMDPANYCAOHTXAZTNWIMIILPACATX...
# zip                                                       2610857
# phone1          504-621-8927810-292-9388856-636-8749907-385-44...
# phone           504-845-1427810-374-9840856-264-4130907-921-20...
# email           jbutt@gmail.comjosephine_darakjy@darakjy.orgar...
# dtype: object

# %%
nba.sum(axis=1)
# Out:
# 0     70116
# 1     48116
# 2      8014
# 3     99501
# 4     45011
# 5     44805
# 6     60632
# 7     95111
# 8     57105
# 9     21224
# 10    19443
# 11    11953
# 12    90034
# 13    44023
# 14    78045
# 15    85013
# 16    37110
# 17    53207
# 18    48180
# 19    61109
# 20    19014
# 21    95111
# 22    75062
# 23    12204
# 24     8846
# 25    54481
# 26    66218
# 27    21601
# 28    10011
# 29    77301
# 30    43215
# 31    88011
# 32     7660
# 33     8812
# 34    10025
# 35    70002
# 36    10011
# 37    93012
# 38    78204
# 39    67410
# 40    97754
# 41    66204
# 42    99708
# 43    33196
# 44    99712
# 45    55343
# 46     2128
# 47    90006
# 48    53711
# 49    19132
# dtype: int64

# %%
nba.sum(axis="columns")
# Out:
# 0     70116
# 1     48116
# 2      8014
# 3     99501
# 4     45011
# 5     44805
# 6     60632
# 7     95111
# 8     57105
# 9     21224
# 10    19443
# 11    11953
# 12    90034
# 13    44023
# 14    78045
# 15    85013
# 16    37110
# 17    53207
# 18    48180
# 19    61109
# 20    19014
# 21    95111
# 22    75062
# 23    12204
# 24     8846
# 25    54481
# 26    66218
# 27    21601
# 28    10011
# 29    77301
# 30    43215
# 31    88011
# 32     7660
# 33     8812
# 34    10025
# 35    70002
# 36    10011
# 37    93012
# 38    78204
# 39    67410
# 40    97754
# 41    66204
# 42    99708
# 43    33196
# 44    99712
# 45    55343
# 46     2128
# 47    90006
# 48    53711
# 49    19132
# dtype: int64

# %%
#select one Coloumn from a DataFrame
nba
# Out:
#    first_name  last_name                   company_name  \
# 0       James       Butt              Benton, John B Jr
# 1   Josephine    Darakjy          Chanay, Jeffrey A Esq
# 2         Art     Venere            Chemel, James L Cpa
# 3       Lenna   Paprocki         Feltz Printing Service
# 4     Donette     Foller            Printing Dimensions
# 5      Simona    Morasca            Chapman, Ross E Esq
# 6      Mitsue    Tollner             Morlong Associates
# 7       Leota   Dilliard               Commercial Press
# 8        Sage     Wieser      Truhlar And Truhlar Attys
# 9        Kris    Marrier        King, Christopher A Esq
# 10      Minna     Amigon              Dorl, James J Esq
# 11       Abel    Maclead            Rangoni Of Florence
# 12      Kiley  Caldarera                    Feiner Bros
# 13   Graciela       Ruta        Buckley Miller & Wright
# 14      Cammy    Albares         Rousseaux, Michael Esq
# 15     Mattie   Poquette         Century Communications
# ...

# %%
nba.first_name
# Out:
# 0         James
# 1     Josephine
# 2           Art
# 3         Lenna
# 4       Donette
# 5        Simona
# 6        Mitsue
# 7         Leota
# 8          Sage
# 9          Kris
# 10        Minna
# 11         Abel
# 12        Kiley
# 13     Graciela
# 14        Cammy
# 15       Mattie
# 16      Meaghan
# 17       Gladys
# 18         Yuki
# 19     Fletcher
# 20        Bette
# 21     Veronika
# 22      Willard
# 23      Maryann
# 24       Alisha
# 25       Allene
# 26       Chanel
# 27      Ezekiel
# 28       Willow
# 29     Bernardo
# 30        Ammie
# 31     Francine
# 32        Ernie
# 33       Albina
# 34      Alishia
# 35      Solange
# 36         Jose
# 37      Rozella
# 38    Valentine
# 39         Kati
# 40     Youlanda
# 41         Dyan
# 42       Roxane
# 43       Lavera
# 44        Erick
# 45       Fatima
# 46         Jina
# 47      Kanisha
# 48      Emerson
# 49        Blair
# Name: first_name, dtype: object

# %%
nba["first_name"]
# Out:
# 0         James
# 1     Josephine
# 2           Art
# 3         Lenna
# 4       Donette
# 5        Simona
# 6        Mitsue
# 7         Leota
# 8          Sage
# 9          Kris
# 10        Minna
# 11         Abel
# 12        Kiley
# 13     Graciela
# 14        Cammy
# 15       Mattie
# 16      Meaghan
# 17       Gladys
# 18         Yuki
# 19     Fletcher
# 20        Bette
# 21     Veronika
# 22      Willard
# 23      Maryann
# 24       Alisha
# 25       Allene
# 26       Chanel
# 27      Ezekiel
# 28       Willow
# 29     Bernardo
# 30        Ammie
# 31     Francine
# 32        Ernie
# 33       Albina
# 34      Alishia
# 35      Solange
# 36         Jose
# 37      Rozella
# 38    Valentine
# 39         Kati
# 40     Youlanda
# 41         Dyan
# 42       Roxane
# 43       Lavera
# 44        Erick
# 45       Fatima
# 46         Jina
# 47      Kanisha
# 48      Emerson
# 49        Blair
# Name: first_name, dtype: object

# %%
#select two or more coloums
nba[["city","county"]]
# Out:
#                city                county
# 0       New Orleans               Orleans
# 1          Brighton            Livingston
# 2        Bridgeport            Gloucester
# 3         Anchorage             Anchorage
# 4          Hamilton                Butler
# 5           Ashland               Ashland
# 6           Chicago                  Cook
# 7          San Jose           Santa Clara
# 8       Sioux Falls             Minnehaha
# 9         Baltimore        Baltimore City
# 10       Kulpsville            Montgomery
# 11    Middle Island               Suffolk
# 12      Los Angeles           Los Angeles
# 13    Chagrin Falls                Geauga
# 14           Laredo                  Webb
# 15          Phoenix              Maricopa
# 16     Mc Minnville                Warren
# 17        Milwaukee             Milwaukee
# 18           Taylor                 Wayne
# 19         Rockford             Winnebago
# 20            Aston              Delaware
# ...

# %%
nba[["county","city",]]
# Out:
#                   county             city
# 0                Orleans      New Orleans
# 1             Livingston         Brighton
# 2             Gloucester       Bridgeport
# 3              Anchorage        Anchorage
# 4                 Butler         Hamilton
# 5                Ashland          Ashland
# 6                   Cook          Chicago
# 7            Santa Clara         San Jose
# 8              Minnehaha      Sioux Falls
# 9         Baltimore City        Baltimore
# 10            Montgomery       Kulpsville
# 11               Suffolk    Middle Island
# 12           Los Angeles      Los Angeles
# 13                Geauga    Chagrin Falls
# 14                  Webb           Laredo
# 15              Maricopa          Phoenix
# 16                Warren     Mc Minnville
# 17             Milwaukee        Milwaukee
# 18                 Wayne           Taylor
# 19             Winnebago         Rockford
# 20              Delaware            Aston
# ...

# %%
select =["city","county"]
nba[select]
# Out:
#                city                county
# 0       New Orleans               Orleans
# 1          Brighton            Livingston
# 2        Bridgeport            Gloucester
# 3         Anchorage             Anchorage
# 4          Hamilton                Butler
# 5           Ashland               Ashland
# 6           Chicago                  Cook
# 7          San Jose           Santa Clara
# 8       Sioux Falls             Minnehaha
# 9         Baltimore        Baltimore City
# 10       Kulpsville            Montgomery
# 11    Middle Island               Suffolk
# 12      Los Angeles           Los Angeles
# 13    Chagrin Falls                Geauga
# 14           Laredo                  Webb
# 15          Phoenix              Maricopa
# 16     Mc Minnville                Warren
# 17        Milwaukee             Milwaukee
# 18           Taylor                 Wayne
# 19         Rockford             Winnebago
# 20            Aston              Delaware
# ...

# %%
#Add new coloumn to add frame

nba.head(3)
# Out:
#   first_name last_name           company_name               address  \
# 0      James      Butt      Benton, John B Jr    6649 N Blue Gum St
# 1  Josephine   Darakjy  Chanay, Jeffrey A Esq   4 B Blue Ridge Blvd
# 2        Art    Venere    Chemel, James L Cpa  8 W Cerritos Ave #54
#
#           city      county state    zip        phone1         phone  \
# 0  New Orleans     Orleans    LA  70116  504-621-8927  504-845-1427
# 1     Brighton  Livingston    MI  48116  810-292-9388  810-374-9840
# 2   Bridgeport  Gloucester    NJ   8014  856-636-8749  856-264-4130
#
#                            email
# 0                jbutt@gmail.com
# 1  josephine_darakjy@darakjy.org
# 2                 art@venere.org

# %%
nba["land mark"]="basketball"

# %%
nba
# Out:
#    first_name  last_name                   company_name  \
# 0       James       Butt              Benton, John B Jr
# 1   Josephine    Darakjy          Chanay, Jeffrey A Esq
# 2         Art     Venere            Chemel, James L Cpa
# 3       Lenna   Paprocki         Feltz Printing Service
# 4     Donette     Foller            Printing Dimensions
# 5      Simona    Morasca            Chapman, Ross E Esq
# 6      Mitsue    Tollner             Morlong Associates
# 7       Leota   Dilliard               Commercial Press
# 8        Sage     Wieser      Truhlar And Truhlar Attys
# 9        Kris    Marrier        King, Christopher A Esq
# 10      Minna     Amigon              Dorl, James J Esq
# 11       Abel    Maclead            Rangoni Of Florence
# 12      Kiley  Caldarera                    Feiner Bros
# 13   Graciela       Ruta        Buckley Miller & Wright
# 14      Cammy    Albares         Rousseaux, Michael Esq
# 15     Mattie   Poquette         Century Communications
# ...

# %%
nba = pd.read_csv("C:\\Users\\HP\\Downloads\\50-contacts.csv")

# %%
nba
# Out:
#    first_name  last_name                   company_name  \
# 0       James       Butt              Benton, John B Jr
# 1   Josephine    Darakjy          Chanay, Jeffrey A Esq
# 2         Art     Venere            Chemel, James L Cpa
# 3       Lenna   Paprocki         Feltz Printing Service
# 4     Donette     Foller            Printing Dimensions
# 5      Simona    Morasca            Chapman, Ross E Esq
# 6      Mitsue    Tollner             Morlong Associates
# 7       Leota   Dilliard               Commercial Press
# 8        Sage     Wieser      Truhlar And Truhlar Attys
# 9        Kris    Marrier        King, Christopher A Esq
# 10      Minna     Amigon              Dorl, James J Esq
# 11       Abel    Maclead            Rangoni Of Florence
# 12      Kiley  Caldarera                    Feiner Bros
# 13   Graciela       Ruta        Buckley Miller & Wright
# 14      Cammy    Albares         Rousseaux, Michael Esq
# 15     Mattie   Poquette         Century Communications
# ...

# %%
#insert
nba.insert(3,column="sport",value ="Basketball")

# %%
nba
# Out:
#    first_name  last_name                   company_name       sport  \
# 0       James       Butt              Benton, John B Jr  Basketball
# 1   Josephine    Darakjy          Chanay, Jeffrey A Esq  Basketball
# 2         Art     Venere            Chemel, James L Cpa  Basketball
# 3       Lenna   Paprocki         Feltz Printing Service  Basketball
# 4     Donette     Foller            Printing Dimensions  Basketball
# 5      Simona    Morasca            Chapman, Ross E Esq  Basketball
# 6      Mitsue    Tollner             Morlong Associates  Basketball
# 7       Leota   Dilliard               Commercial Press  Basketball
# 8        Sage     Wieser      Truhlar And Truhlar Attys  Basketball
# 9        Kris    Marrier        King, Christopher A Esq  Basketball
# 10      Minna     Amigon              Dorl, James J Esq  Basketball
# 11       Abel    Maclead            Rangoni Of Florence  Basketball
# 12      Kiley  Caldarera                    Feiner Bros  Basketball
# ...

# %%
nba = pd.read_csv("C:\\Users\\HP\\Downloads\\50-contacts.csv")

# %%
#Broad casting opeartions
nba["zip"].add(5)
# Out:
# 0     70121
# 1     48121
# 2      8019
# 3     99506
# 4     45016
# 5     44810
# 6     60637
# 7     95116
# 8     57110
# 9     21229
# 10    19448
# 11    11958
# 12    90039
# 13    44028
# 14    78050
# 15    85018
# 16    37115
# 17    53212
# 18    48185
# 19    61114
# 20    19019
# 21    95116
# 22    75067
# 23    12209
# 24     8851
# 25    54486
# 26    66223
# 27    21606
# 28    10016
# 29    77306
# 30    43220
# 31    88016
# 32     7665
# 33     8817
# 34    10030
# 35    70007
# 36    10016
# 37    93017
# 38    78209
# 39    67415
# 40    97759
# 41    66209
# 42    99713
# 43    33201
# 44    99717
# 45    55348
# 46     2133
# 47    90011
# 48    53716
# 49    19137
# Name: zip, dtype: int64

# %%
nba["zip"].sub(5)
# Out:
# 0     70111
# 1     48111
# 2      8009
# 3     99496
# 4     45006
# 5     44800
# 6     60627
# 7     95106
# 8     57100
# 9     21219
# 10    19438
# 11    11948
# 12    90029
# 13    44018
# 14    78040
# 15    85008
# 16    37105
# 17    53202
# 18    48175
# 19    61104
# 20    19009
# 21    95106
# 22    75057
# 23    12199
# 24     8841
# 25    54476
# 26    66213
# 27    21596
# 28    10006
# 29    77296
# 30    43210
# 31    88006
# 32     7655
# 33     8807
# 34    10020
# 35    69997
# 36    10006
# 37    93007
# 38    78199
# 39    67405
# 40    97749
# 41    66199
# 42    99703
# 43    33191
# 44    99707
# 45    55338
# 46     2123
# 47    90001
# 48    53706
# 49    19127
# Name: zip, dtype: int64

# %%
#Adding new coloumn with updated values of zip code
nba["New zip code"]=nba["zip"].mul(5)

# %%
nba
# Out:
#    first_name  last_name                   company_name  \
# 0       James       Butt              Benton, John B Jr
# 1   Josephine    Darakjy          Chanay, Jeffrey A Esq
# 2         Art     Venere            Chemel, James L Cpa
# 3       Lenna   Paprocki         Feltz Printing Service
# 4     Donette     Foller            Printing Dimensions
# 5      Simona    Morasca            Chapman, Ross E Esq
# 6      Mitsue    Tollner             Morlong Associates
# 7       Leota   Dilliard               Commercial Press
# 8        Sage     Wieser      Truhlar And Truhlar Attys
# 9        Kris    Marrier        King, Christopher A Esq
# 10      Minna     Amigon              Dorl, James J Esq
# 11       Abel    Maclead            Rangoni Of Florence
# 12      Kiley  Caldarera                    Feiner Bros
# 13   Graciela       Ruta        Buckley Miller & Wright
# 14      Cammy    Albares         Rousseaux, Michael Esq
# 15     Mattie   Poquette         Century Communications
# ...

# %%
nba = pd.read_csv("C:\\Users\\HP\\Downloads\\50-contacts.csv")

# %%
nba["county"].value_counts()
# Out:
# New York                3
# Los Angeles             2
# Johnson                 2
# Fairbanks North Star    2
# Suffolk                 2
# Middlesex               2
# Santa Clara             2
# Montgomery              2
# Gloucester              1
# Milwaukee               1
# Ashland                 1
# Maricopa                1
# Orleans                 1
# Minnehaha               1
# Bexar                   1
# Ventura                 1
# Albany                  1
# Hennepin                1
# Wayne                   1
# Dallas                  1
# Geauga                  1
# Jefferson               1
# Baltimore City          1
# Dickinson               1
# Talbot                  1
# Delaware                1
# Cook                    1
# Butler                  1
# Philadelphia            1
# Dane                    1
# Livingston              1
# Webb                    1
# Bergen                  1
# Portage                 1
# Winnebago               1
# ...

# %%
#Drop rows and null values
nba.dropna()
# Out:
#    first_name  last_name                   company_name  \
# 0       James       Butt              Benton, John B Jr
# 1   Josephine    Darakjy          Chanay, Jeffrey A Esq
# 2         Art     Venere            Chemel, James L Cpa
# 3       Lenna   Paprocki         Feltz Printing Service
# 4     Donette     Foller            Printing Dimensions
# 5      Simona    Morasca            Chapman, Ross E Esq
# 6      Mitsue    Tollner             Morlong Associates
# 7       Leota   Dilliard               Commercial Press
# 8        Sage     Wieser      Truhlar And Truhlar Attys
# 9        Kris    Marrier        King, Christopher A Esq
# 10      Minna     Amigon              Dorl, James J Esq
# 11       Abel    Maclead            Rangoni Of Florence
# 12      Kiley  Caldarera                    Feiner Bros
# 13   Graciela       Ruta        Buckley Miller & Wright
# 14      Cammy    Albares         Rousseaux, Michael Esq
# 15     Mattie   Poquette         Century Communications
# ...

# %%
nba.dropna(axis=1)
nba.head()
# Out:
#   first_name last_name            company_name               address  \
# 0      James      Butt       Benton, John B Jr    6649 N Blue Gum St
# 1  Josephine   Darakjy   Chanay, Jeffrey A Esq   4 B Blue Ridge Blvd
# 2        Art    Venere     Chemel, James L Cpa  8 W Cerritos Ave #54
# 3      Lenna  Paprocki  Feltz Printing Service           639 Main St
# 4    Donette    Foller     Printing Dimensions          34 Center St
#
#           city      county state    zip        phone1         phone  \
# 0  New Orleans     Orleans    LA  70116  504-621-8927  504-845-1427
# 1     Brighton  Livingston    MI  48116  810-292-9388  810-374-9840
# 2   Bridgeport  Gloucester    NJ   8014  856-636-8749  856-264-4130
# 3    Anchorage   Anchorage    AK  99501  907-385-4412  907-921-2010
# 4     Hamilton      Butler    OH  45011  513-570-1893  513-549-4561
#
#                            email
# 0                jbutt@gmail.com
# 1  josephine_darakjy@darakjy.org
# 2                 art@venere.org
# ...

# %%
nba = pd.read_csv("C:\\Users\\HP\\Downloads\\50-contacts.csv")

# %%
nba
# Out:
#    first_name  last_name                   company_name  \
# 0       James       Butt              Benton, John B Jr
# 1   Josephine    Darakjy          Chanay, Jeffrey A Esq
# 2         Art     Venere            Chemel, James L Cpa
# 3       Lenna   Paprocki         Feltz Printing Service
# 4     Donette     Foller            Printing Dimensions
# 5      Simona    Morasca            Chapman, Ross E Esq
# 6      Mitsue    Tollner             Morlong Associates
# 7       Leota   Dilliard               Commercial Press
# 8        Sage     Wieser      Truhlar And Truhlar Attys
# 9        Kris    Marrier        King, Christopher A Esq
# 10      Minna     Amigon              Dorl, James J Esq
# 11       Abel    Maclead            Rangoni Of Florence
# 12      Kiley  Caldarera                    Feiner Bros
# 13   Graciela       Ruta        Buckley Miller & Wright
# 14      Cammy    Albares         Rousseaux, Michael Esq
# 15     Mattie   Poquette         Century Communications
# ...

# %%
#To check the particualr coloumn the null vales
nba.dropna(subset =["state"])
# Out:
#    first_name  last_name                   company_name  \
# 0       James       Butt              Benton, John B Jr
# 1   Josephine    Darakjy          Chanay, Jeffrey A Esq
# 2         Art     Venere            Chemel, James L Cpa
# 3       Lenna   Paprocki         Feltz Printing Service
# 4     Donette     Foller            Printing Dimensions
# 5      Simona    Morasca            Chapman, Ross E Esq
# 6      Mitsue    Tollner             Morlong Associates
# 7       Leota   Dilliard               Commercial Press
# 8        Sage     Wieser      Truhlar And Truhlar Attys
# 10      Minna     Amigon              Dorl, James J Esq
# 11       Abel    Maclead            Rangoni Of Florence
# 12      Kiley  Caldarera                    Feiner Bros
# 13   Graciela       Ruta        Buckley Miller & Wright
# 14      Cammy    Albares         Rousseaux, Michael Esq
# 15     Mattie   Poquette         Century Communications
# 16    Meaghan     Garufi             Bolton, Wilbur Esq
# ...

# %%
nba = pd.read_csv("C:\\Users\\HP\\Downloads\\50-contacts.csv")

# %%
#fill null values with fillna method
nba.fillna(0)
# Out:
#    first_name  last_name                   company_name  \
# 0       James       Butt              Benton, John B Jr
# 1   Josephine    Darakjy          Chanay, Jeffrey A Esq
# 2         Art     Venere            Chemel, James L Cpa
# 3       Lenna   Paprocki         Feltz Printing Service
# 4     Donette     Foller            Printing Dimensions
# 5      Simona    Morasca            Chapman, Ross E Esq
# 6      Mitsue    Tollner             Morlong Associates
# 7       Leota   Dilliard               Commercial Press
# 8        Sage     Wieser      Truhlar And Truhlar Attys
# 9        Kris    Marrier        King, Christopher A Esq
# 10      Minna     Amigon              Dorl, James J Esq
# 11       Abel    Maclead            Rangoni Of Florence
# 12      Kiley  Caldarera                    Feiner Bros
# 13   Graciela       Ruta        Buckley Miller & Wright
# 14      Cammy    Albares         Rousseaux, Michael Esq
# 15     Mattie   Poquette         Century Communications
# ...

# %%
#dealing with strings
nba["city"].fillna("No city",inplace=True)

# %%
nba
# Out:
#    first_name  last_name                   company_name  \
# 0       James       Butt              Benton, John B Jr
# 1   Josephine    Darakjy          Chanay, Jeffrey A Esq
# 2         Art     Venere            Chemel, James L Cpa
# 3       Lenna   Paprocki         Feltz Printing Service
# 4     Donette     Foller            Printing Dimensions
# 5      Simona    Morasca            Chapman, Ross E Esq
# 6      Mitsue    Tollner             Morlong Associates
# 7       Leota   Dilliard               Commercial Press
# 8        Sage     Wieser      Truhlar And Truhlar Attys
# 9        Kris    Marrier        King, Christopher A Esq
# 10      Minna     Amigon              Dorl, James J Esq
# 11       Abel    Maclead            Rangoni Of Florence
# 12      Kiley  Caldarera                    Feiner Bros
# 13   Graciela       Ruta        Buckley Miller & Wright
# 14      Cammy    Albares         Rousseaux, Michael Esq
# 15     Mattie   Poquette         Century Communications
# ...

# %%
#.astype method
nba = pd.read_csv("C:\\Users\\HP\\Downloads\\50-contacts.csv")
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   first_name    50 non-null     object
#  1   last_name     50 non-null     object
#  2   company_name  50 non-null     object
#  3   address       50 non-null     object
#  4   city          46 non-null     object
#  5   county        50 non-null     object
#  6   state         46 non-null     object
#  7   zip           50 non-null     int64
#  8   phone1        50 non-null     object
#  9   phone         50 non-null     object
#  10  email         50 non-null     object
# dtypes: int64(1), object(10)
# memory usage: 4.4+ KB

# %%
nba = pd.read_csv("C:\\Users\\HP\\Downloads\\50-contacts.csv").dropna(how ="all")
nba
# Out:
#    first_name  last_name                   company_name  \
# 0       James       Butt              Benton, John B Jr
# 1   Josephine    Darakjy          Chanay, Jeffrey A Esq
# 2         Art     Venere            Chemel, James L Cpa
# 3       Lenna   Paprocki         Feltz Printing Service
# 4     Donette     Foller            Printing Dimensions
# 5      Simona    Morasca            Chapman, Ross E Esq
# 6      Mitsue    Tollner             Morlong Associates
# 7       Leota   Dilliard               Commercial Press
# 8        Sage     Wieser      Truhlar And Truhlar Attys
# 9        Kris    Marrier        King, Christopher A Esq
# 10      Minna     Amigon              Dorl, James J Esq
# 11       Abel    Maclead            Rangoni Of Florence
# 12      Kiley  Caldarera                    Feiner Bros
# 13   Graciela       Ruta        Buckley Miller & Wright
# 14      Cammy    Albares         Rousseaux, Michael Esq
# 15     Mattie   Poquette         Century Communications
# ...

# %%
nba["state"].fillna(0,inplace=True)
nba["city"].fillna("None",inplace =True)

# %%
nba
# Out:
#    first_name  last_name                   company_name  \
# 0       James       Butt              Benton, John B Jr
# 1   Josephine    Darakjy          Chanay, Jeffrey A Esq
# 2         Art     Venere            Chemel, James L Cpa
# 3       Lenna   Paprocki         Feltz Printing Service
# 4     Donette     Foller            Printing Dimensions
# 5      Simona    Morasca            Chapman, Ross E Esq
# 6      Mitsue    Tollner             Morlong Associates
# 7       Leota   Dilliard               Commercial Press
# 8        Sage     Wieser      Truhlar And Truhlar Attys
# 9        Kris    Marrier        King, Christopher A Esq
# 10      Minna     Amigon              Dorl, James J Esq
# 11       Abel    Maclead            Rangoni Of Florence
# 12      Kiley  Caldarera                    Feiner Bros
# 13   Graciela       Ruta        Buckley Miller & Wright
# 14      Cammy    Albares         Rousseaux, Michael Esq
# 15     Mattie   Poquette         Century Communications
# ...

# %%
#how to check the unique values
nba["county"].nunique()
# Out:
# 41

# %%
nba["county"] = nba["county"].astype("category")

# %%
nba.head()
# Out:
#   first_name last_name            company_name               address  \
# 0      James      Butt       Benton, John B Jr    6649 N Blue Gum St
# 1  Josephine   Darakjy   Chanay, Jeffrey A Esq   4 B Blue Ridge Blvd
# 2        Art    Venere     Chemel, James L Cpa  8 W Cerritos Ave #54
# 3      Lenna  Paprocki  Feltz Printing Service           639 Main St
# 4    Donette    Foller     Printing Dimensions          34 Center St
#
#           city      county state    zip        phone1         phone  \
# 0  New Orleans     Orleans    LA  70116  504-621-8927  504-845-1427
# 1     Brighton  Livingston    MI  48116  810-292-9388  810-374-9840
# 2   Bridgeport  Gloucester    NJ   8014  856-636-8749  856-264-4130
# 3    Anchorage   Anchorage    AK  99501  907-385-4412  907-921-2010
# 4     Hamilton      Butler    OH  45011  513-570-1893  513-549-4561
#
#                            email
# 0                jbutt@gmail.com
# 1  josephine_darakjy@darakjy.org
# 2                 art@venere.org
# ...

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   first_name    50 non-null     object
#  1   last_name     50 non-null     object
#  2   company_name  50 non-null     object
#  3   address       50 non-null     object
#  4   city          46 non-null     object
#  5   county        50 non-null     object
#  6   state         46 non-null     object
#  7   zip           50 non-null     int64
#  8   phone1        50 non-null     object
#  9   phone         50 non-null     object
#  10  email         50 non-null     object
# dtypes: int64(1), object(10)
# memory usage: 4.4+ KB

# %%
nba = pd.read_csv("C:\\Users\\HP\\Downloads\\50-contacts.csv")
nba.head()
# Out:
#   first_name last_name            company_name               address  \
# 0      James      Butt       Benton, John B Jr    6649 N Blue Gum St
# 1  Josephine   Darakjy   Chanay, Jeffrey A Esq   4 B Blue Ridge Blvd
# 2        Art    Venere     Chemel, James L Cpa  8 W Cerritos Ave #54
# 3      Lenna  Paprocki  Feltz Printing Service           639 Main St
# 4    Donette    Foller     Printing Dimensions          34 Center St
#
#           city      county state    zip        phone1         phone  \
# 0  New Orleans     Orleans    LA  70116  504-621-8927  504-845-1427
# 1     Brighton  Livingston    MI  48116  810-292-9388  810-374-9840
# 2   Bridgeport  Gloucester    NJ   8014  856-636-8749  856-264-4130
# 3    Anchorage   Anchorage    AK  99501  907-385-4412  907-921-2010
# 4     Hamilton      Butler    OH  45011  513-570-1893  513-549-4561
#
#                            email
# 0                jbutt@gmail.com
# 1  josephine_darakjy@darakjy.org
# 2                 art@venere.org
# ...

# %%
nba.sort_values("first_name",ascending=False)
# Out:
#    first_name  last_name                   company_name  \
# 18       Yuki    Whobrey        Farmers Insurance Group
# 40   Youlanda   Schemmer                 Tri M Tool Inc
# 28     Willow      Kusko                      U Pull It
# 22    Willard    Kolmetz          Ingalls, Donald R Esq
# 21   Veronika     Inouye                C 4 Network Inc
# 38  Valentine    Gillian           Fbs Business Finance
# 35    Solange     Shinko              Mosocco, Ronald A
# 5      Simona    Morasca            Chapman, Ross E Esq
# 8        Sage     Wieser      Truhlar And Truhlar Attys
# 37    Rozella   Ostrosky                Parkway Company
# 42     Roxane    Campain             Rapid Trading Intl
# 6      Mitsue    Tollner             Morlong Associates
# 10      Minna     Amigon              Dorl, James J Esq
# 16    Meaghan     Garufi             Bolton, Wilbur Esq
# 15     Mattie   Poquette         Century Communications
# 23    Maryann    Royster          Franklin, Peter L Esq
# ...

# %%
nba = pd.read_csv("C:\\Users\\HP\\Downloads\\50-contacts.csv")
nba.head()
# Out:
#   first_name last_name            company_name               address  \
# 0      James      Butt       Benton, John B Jr    6649 N Blue Gum St
# 1  Josephine   Darakjy   Chanay, Jeffrey A Esq   4 B Blue Ridge Blvd
# 2        Art    Venere     Chemel, James L Cpa  8 W Cerritos Ave #54
# 3      Lenna  Paprocki  Feltz Printing Service           639 Main St
# 4    Donette    Foller     Printing Dimensions          34 Center St
#
#           city      county state    zip        phone1         phone  \
# 0  New Orleans     Orleans    LA  70116  504-621-8927  504-845-1427
# 1     Brighton  Livingston    MI  48116  810-292-9388  810-374-9840
# 2   Bridgeport  Gloucester    NJ   8014  856-636-8749  856-264-4130
# 3    Anchorage   Anchorage    AK  99501  907-385-4412  907-921-2010
# 4     Hamilton      Butler    OH  45011  513-570-1893  513-549-4561
#
#                            email
# 0                jbutt@gmail.com
# 1  josephine_darakjy@darakjy.org
# 2                 art@venere.org
# ...

# %%
#sort two or more coloumns
nba.sort_values(["first_name","last_name"])
# Out:
#    first_name  last_name                   company_name  \
# 11       Abel    Maclead            Rangoni Of Florence
# 33     Albina      Glick           Giampetro, Anthony D
# 24     Alisha  Slusarski              Wtlz Power 107 Fm
# 34    Alishia      Sergi        Milford Enterprises Inc
# 25     Allene   Iturbide             Ledecky, David Esq
# 30      Ammie     Corrio             Moskowitz, Barry S
# 2         Art     Venere            Chemel, James L Cpa
# 29   Bernardo    Figeroa             Clark, Richard Cpa
# 20      Bette      Nicka                   Sport En Art
# 49      Blair      Malet  Bollinger Mach Shp & Shipyard
# 14      Cammy    Albares         Rousseaux, Michael Esq
# 26     Chanel      Caudy         Professional Image Inc
# 4     Donette     Foller            Printing Dimensions
# 41       Dyan    Oldroyd      International Eyelets Inc
# 48    Emerson     Bowley                    Knights Inn
# 44      Erick    Ferencz        Cindy Turner Associates
# ...

# %%
df = pd.read_csv("C:\\Users\\HP\\Downloads\\50-contacts.csv")

# %%
#Only county name with Middlesex will return
df[df["county"]=="Middlesex"]
# Out:
#    first_name  last_name          company_name        address       city  \
# 24     Alisha  Slusarski     Wtlz Power 107 Fm  3273 State St  Middlesex
# 33     Albina      Glick  Giampetro, Anthony D     4 Ralph Ct   Dunellen
#
#        county state   zip        phone1         phone                 email
# 24  Middlesex    NJ  8846  732-658-3154  732-635-3453  alisha@slusarski.com
# 33  Middlesex    NJ  8812  732-924-7882  732-782-6701      albina@glick.com

# %%
df[df["zip"] <9000]
# Out:
#    first_name  last_name          company_name               address  \
# 2         Art     Venere   Chemel, James L Cpa  8 W Cerritos Ave #54
# 24     Alisha  Slusarski     Wtlz Power 107 Fm         3273 State St
# 32      Ernie   Stenseth        Knwz Newsradio       45 E Liberty St
# 33     Albina      Glick  Giampetro, Anthony D            4 Ralph Ct
# 46       Jina   Briddick    Grace Pastries Inc       38938 Park Blvd
#
#                city      county state   zip        phone1         phone  \
# 2        Bridgeport  Gloucester    NJ  8014  856-636-8749  856-264-4130
# 24        Middlesex   Middlesex    NJ  8846  732-658-3154  732-635-3453
# 32  Ridgefield Park      Bergen    NJ  7660  201-709-6245  201-387-9093
# 33         Dunellen   Middlesex    NJ  8812  732-924-7882  732-782-6701
# 46              NaN     Suffolk    MA  2128  617-399-5124  617-997-5771
#
#                          email
# 2               art@venere.org
# 24        alisha@slusarski.com
# ...

# %%
#using more than one condition
mask1 = df["county"] =="Middlesex"
mask2 = df["city"] =="Dunellen"

df[mask1 &mask2]
# Out:
#    first_name last_name          company_name     address      city  \
# 33     Albina     Glick  Giampetro, Anthony D  4 Ralph Ct  Dunellen
#
#        county state   zip        phone1         phone             email
# 33  Middlesex    NJ  8812  732-924-7882  732-782-6701  albina@glick.com

# %%
mask1 = df["county"] =="Middlesex"
mask2 = df["city"] =="Dunellen"

df[mask1 &mask2]
df[mask1 | mask2]
# Out:
#    first_name  last_name          company_name        address       city  \
# 24     Alisha  Slusarski     Wtlz Power 107 Fm  3273 State St  Middlesex
# 33     Albina      Glick  Giampetro, Anthony D     4 Ralph Ct   Dunellen
#
#        county state   zip        phone1         phone                 email
# 24  Middlesex    NJ  8846  732-658-3154  732-635-3453  alisha@slusarski.com
# 33  Middlesex    NJ  8812  732-924-7882  732-782-6701      albina@glick.com

# %%
mask1 = df["county"] =="Middlesex"
mask2 = df["county"] =="Gloucester"
mask3 = df["county"]=="Bergen"

df[mask1 | mask2 | mask3]
# Out:
#    first_name  last_name          company_name               address  \
# 2         Art     Venere   Chemel, James L Cpa  8 W Cerritos Ave #54
# 24     Alisha  Slusarski     Wtlz Power 107 Fm         3273 State St
# 32      Ernie   Stenseth        Knwz Newsradio       45 E Liberty St
# 33     Albina      Glick  Giampetro, Anthony D            4 Ralph Ct
#
#                city      county state   zip        phone1         phone  \
# 2        Bridgeport  Gloucester    NJ  8014  856-636-8749  856-264-4130
# 24        Middlesex   Middlesex    NJ  8846  732-658-3154  732-635-3453
# 32  Ridgefield Park      Bergen    NJ  7660  201-709-6245  201-387-9093
# 33         Dunellen   Middlesex    NJ  8812  732-924-7882  732-782-6701
#
#                      email
# 2           art@venere.org
# 24    alisha@slusarski.com
# 32  ernie_stenseth@aol.com
# 33        albina@glick.com

# %%
mask = df["county"].isin(["Middlesex","Gloucester","Bergen"])
df[mask]
# Out:
#    first_name  last_name          company_name               address  \
# 2         Art     Venere   Chemel, James L Cpa  8 W Cerritos Ave #54
# 24     Alisha  Slusarski     Wtlz Power 107 Fm         3273 State St
# 32      Ernie   Stenseth        Knwz Newsradio       45 E Liberty St
# 33     Albina      Glick  Giampetro, Anthony D            4 Ralph Ct
#
#                city      county state   zip        phone1         phone  \
# 2        Bridgeport  Gloucester    NJ  8014  856-636-8749  856-264-4130
# 24        Middlesex   Middlesex    NJ  8846  732-658-3154  732-635-3453
# 32  Ridgefield Park      Bergen    NJ  7660  201-709-6245  201-387-9093
# 33         Dunellen   Middlesex    NJ  8812  732-924-7882  732-782-6701
#
#                      email
# 2           art@venere.org
# 24    alisha@slusarski.com
# 32  ernie_stenseth@aol.com
# 33        albina@glick.com

# %%
#isnull() and not null
df
# Out:
#    first_name  last_name                   company_name  \
# 0       James       Butt              Benton, John B Jr
# 1   Josephine    Darakjy          Chanay, Jeffrey A Esq
# 2         Art     Venere            Chemel, James L Cpa
# 3       Lenna   Paprocki         Feltz Printing Service
# 4     Donette     Foller            Printing Dimensions
# 5      Simona    Morasca            Chapman, Ross E Esq
# 6      Mitsue    Tollner             Morlong Associates
# 7       Leota   Dilliard               Commercial Press
# 8        Sage     Wieser      Truhlar And Truhlar Attys
# 9        Kris    Marrier        King, Christopher A Esq
# 10      Minna     Amigon              Dorl, James J Esq
# 11       Abel    Maclead            Rangoni Of Florence
# 12      Kiley  Caldarera                    Feiner Bros
# 13   Graciela       Ruta        Buckley Miller & Wright
# 14      Cammy    Albares         Rousseaux, Michael Esq
# 15     Mattie   Poquette         Century Communications
# ...

# %%
df["state"]
# Out:
# 0      LA
# 1      MI
# 2      NJ
# 3      AK
# 4      OH
# 5      OH
# 6      IL
# 7      CA
# 8      SD
# 9     NaN
# 10     PA
# 11     NY
# 12     CA
# 13     OH
# 14     TX
# 15     AZ
# 16     TN
# 17     WI
# 18     MI
# 19    NaN
# 20     PA
# 21     CA
# 22     TX
# 23     NY
# 24     NJ
# 25     WI
# 26     KS
# 27     MD
# 28     NY
# 29     TX
# 30     OH
# 31     NM
# 32     NJ
# 33     NJ
# 34     NY
# 35     LA
# 36     NY
# 37    NaN
# 38     TX
# 39     KS
# 40     OR
# 41    NaN
# 42     AK
# 43     FL
# 44     AK
# 45     MN
# 46     MA
# 47     CA
# 48     WI
# 49     PA
# Name: state, dtype: object

# %%
mask = df["state"].isnull()
df[mask]
# Out:
#    first_name last_name               company_name                address  \
# 9        Kris   Marrier    King, Christopher A Esq  228 Runamuck Pl #2808
# 19   Fletcher     Flosi     Post Box Services Plus    394 Manchester Blvd
# 37    Rozella  Ostrosky            Parkway Company         17 Morena Blvd
# 41       Dyan   Oldroyd  International Eyelets Inc      7219 Woodfield Rd
#
#          city          county state    zip        phone1         phone  \
# 9   Baltimore  Baltimore City   NaN  21224  410-655-8723  410-804-4694
# 19   Rockford       Winnebago   NaN  61109  815-828-2147  815-426-5657
# 37  Camarillo         Ventura   NaN  93012  805-832-6163  805-609-1531
# 41        NaN         Johnson   NaN  66204  913-413-4604  913-645-8918
#
#                             email
# 9                  kris@gmail.com
# 19       fletcher.flosi@yahoo.com
# 37  rozella.ostrosky@ostrosky.com
# 41               doldroyd@aol.com

# %%
mask = df["state"].notnull()
df[mask]
# Out:
#    first_name  last_name                   company_name  \
# 0       James       Butt              Benton, John B Jr
# 1   Josephine    Darakjy          Chanay, Jeffrey A Esq
# 2         Art     Venere            Chemel, James L Cpa
# 3       Lenna   Paprocki         Feltz Printing Service
# 4     Donette     Foller            Printing Dimensions
# 5      Simona    Morasca            Chapman, Ross E Esq
# 6      Mitsue    Tollner             Morlong Associates
# 7       Leota   Dilliard               Commercial Press
# 8        Sage     Wieser      Truhlar And Truhlar Attys
# 10      Minna     Amigon              Dorl, James J Esq
# 11       Abel    Maclead            Rangoni Of Florence
# 12      Kiley  Caldarera                    Feiner Bros
# 13   Graciela       Ruta        Buckley Miller & Wright
# 14      Cammy    Albares         Rousseaux, Michael Esq
# 15     Mattie   Poquette         Century Communications
# 16    Meaghan     Garufi             Bolton, Wilbur Esq
# ...

# %%
#Between key word
df[df["zip"].between(60000,70000)]
# Out:
#    first_name  last_name                   company_name              address  \
# 6      Mitsue    Tollner             Morlong Associates            7 Eads St
# 19   Fletcher      Flosi         Post Box Services Plus  394 Manchester Blvd
# 26     Chanel      Caudy         Professional Image Inc  86 Nw 66th St #8673
# 39       Kati  Rulapaugh  Eder Assocs Consltng Engrs Pc      6980 Dorsett Rd
# 41       Dyan    Oldroyd      International Eyelets Inc    7219 Woodfield Rd
#
#         city     county state    zip        phone1         phone  \
# 6    Chicago       Cook    IL  60632  773-573-6914  773-924-8565
# 19  Rockford  Winnebago   NaN  61109  815-828-2147  815-426-5657
# 26   Shawnee    Johnson    KS  66218  913-388-2079  913-899-1103
# 39   Abilene  Dickinson    KS  67410  785-463-7829  785-219-7724
# 41       NaN    Johnson   NaN  66204  913-413-4604  913-645-8918
#
#                          email
# 6     mitsue_tollner@yahoo.com
# 19    fletcher.flosi@yahoo.com
# ...

# %%
df
# Out:
#    first_name  last_name                   company_name  \
# 0       James       Butt              Benton, John B Jr
# 1   Josephine    Darakjy          Chanay, Jeffrey A Esq
# 2         Art     Venere            Chemel, James L Cpa
# 3       Lenna   Paprocki         Feltz Printing Service
# 4     Donette     Foller            Printing Dimensions
# 5      Simona    Morasca            Chapman, Ross E Esq
# 6      Mitsue    Tollner             Morlong Associates
# 7       Leota   Dilliard               Commercial Press
# 8        Sage     Wieser      Truhlar And Truhlar Attys
# 9        Kris    Marrier        King, Christopher A Esq
# 10      Minna     Amigon              Dorl, James J Esq
# 11       Abel    Maclead            Rangoni Of Florence
# 12      Kiley  Caldarera                    Feiner Bros
# 13   Graciela       Ruta        Buckley Miller & Wright
# 14      Cammy    Albares         Rousseaux, Michael Esq
# 15     Mattie   Poquette         Century Communications
# ...

# %%
df["city"].duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21     True
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34     True
# 35    False
# 36     True
# 37    False
# 38    False
# 39    False
# 40    False
# 41     True
# 42    False
# 43    False
# 44     True
# 45    False
# 46     True
# 47     True
# 48    False
# 49    False
# Name: city, dtype: bool

# %%
mask = ~df["county"].duplicated(keep=False)
df[mask]
# Out:
#    first_name  last_name                   company_name  \
# 0       James       Butt              Benton, John B Jr
# 1   Josephine    Darakjy          Chanay, Jeffrey A Esq
# 2         Art     Venere            Chemel, James L Cpa
# 3       Lenna   Paprocki         Feltz Printing Service
# 4     Donette     Foller            Printing Dimensions
# 5      Simona    Morasca            Chapman, Ross E Esq
# 6      Mitsue    Tollner             Morlong Associates
# 8        Sage     Wieser      Truhlar And Truhlar Attys
# 9        Kris    Marrier        King, Christopher A Esq
# 13   Graciela       Ruta        Buckley Miller & Wright
# 14      Cammy    Albares         Rousseaux, Michael Esq
# 15     Mattie   Poquette         Century Communications
# 16    Meaghan     Garufi             Bolton, Wilbur Esq
# 17     Gladys        Rim          T M Byxbee Company Pc
# 18       Yuki    Whobrey        Farmers Insurance Group
# 19   Fletcher      Flosi         Post Box Services Plus
# ...

# %%
df.drop_duplicates(subset=["city"],keep="first")
# Out:
#    first_name  last_name                   company_name  \
# 0       James       Butt              Benton, John B Jr
# 1   Josephine    Darakjy          Chanay, Jeffrey A Esq
# 2         Art     Venere            Chemel, James L Cpa
# 3       Lenna   Paprocki         Feltz Printing Service
# 4     Donette     Foller            Printing Dimensions
# 5      Simona    Morasca            Chapman, Ross E Esq
# 6      Mitsue    Tollner             Morlong Associates
# 7       Leota   Dilliard               Commercial Press
# 8        Sage     Wieser      Truhlar And Truhlar Attys
# 9        Kris    Marrier        King, Christopher A Esq
# 10      Minna     Amigon              Dorl, James J Esq
# 11       Abel    Maclead            Rangoni Of Florence
# 12      Kiley  Caldarera                    Feiner Bros
# 13   Graciela       Ruta        Buckley Miller & Wright
# 14      Cammy    Albares         Rousseaux, Michael Esq
# 15     Mattie   Poquette         Century Communications
# ...

# %%
m = df["city"].unique()
len(m)
# Out:
# 43

# %%
df["city"].nunique()
# Out:
# 42

# %%
#Data extraction
data = pd.read_csv("C:\\Users\\HP\\Downloads\\50-contacts.csv")

# %%
data
# Out:
#    first_name  last_name                   company_name  \
# 0       James       Butt              Benton, John B Jr
# 1   Josephine    Darakjy          Chanay, Jeffrey A Esq
# 2         Art     Venere            Chemel, James L Cpa
# 3       Lenna   Paprocki         Feltz Printing Service
# 4     Donette     Foller            Printing Dimensions
# 5      Simona    Morasca            Chapman, Ross E Esq
# 6      Mitsue    Tollner             Morlong Associates
# 7       Leota   Dilliard               Commercial Press
# 8        Sage     Wieser      Truhlar And Truhlar Attys
# 9        Kris    Marrier        King, Christopher A Esq
# 10      Minna     Amigon              Dorl, James J Esq
# 11       Abel    Maclead            Rangoni Of Florence
# 12      Kiley  Caldarera                    Feiner Bros
# 13   Graciela       Ruta        Buckley Miller & Wright
# 14      Cammy    Albares         Rousseaux, Michael Esq
# 15     Mattie   Poquette         Century Communications
# ...

# %%
data.set_index(keys = "county")
# Out:
#                      first_name  last_name                   company_name  \
# county
# Orleans                   James       Butt              Benton, John B Jr
# Livingston            Josephine    Darakjy          Chanay, Jeffrey A Esq
# Gloucester                  Art     Venere            Chemel, James L Cpa
# Anchorage                 Lenna   Paprocki         Feltz Printing Service
# Butler                  Donette     Foller            Printing Dimensions
# Ashland                  Simona    Morasca            Chapman, Ross E Esq
# Cook                     Mitsue    Tollner             Morlong Associates
# Santa Clara               Leota   Dilliard               Commercial Press
# Minnehaha                  Sage     Wieser      Truhlar And Truhlar Attys
# Baltimore City             Kris    Marrier        King, Christopher A Esq
# Montgomery                Minna     Amigon              Dorl, James J Esq
# Suffolk                    Abel    Maclead            Rangoni Of Florence
# ...

# %%
data.reset_index(drop=True)
# Out:
#    first_name  last_name                   company_name  \
# 0       James       Butt              Benton, John B Jr
# 1   Josephine    Darakjy          Chanay, Jeffrey A Esq
# 2         Art     Venere            Chemel, James L Cpa
# 3       Lenna   Paprocki         Feltz Printing Service
# 4     Donette     Foller            Printing Dimensions
# 5      Simona    Morasca            Chapman, Ross E Esq
# 6      Mitsue    Tollner             Morlong Associates
# 7       Leota   Dilliard               Commercial Press
# 8        Sage     Wieser      Truhlar And Truhlar Attys
# 9        Kris    Marrier        King, Christopher A Esq
# 10      Minna     Amigon              Dorl, James J Esq
# 11       Abel    Maclead            Rangoni Of Florence
# 12      Kiley  Caldarera                    Feiner Bros
# 13   Graciela       Ruta        Buckley Miller & Wright
# 14      Cammy    Albares         Rousseaux, Michael Esq
# 15     Mattie   Poquette         Century Communications
# ...

# %%
#extract rows
data = pd.read_csv("C:\\Users\\HP\\Downloads\\50-contacts.csv",index_col="city")

# %%
data
# Out:
#                 first_name  last_name                   company_name  \
# city
# New Orleans          James       Butt              Benton, John B Jr
# Brighton         Josephine    Darakjy          Chanay, Jeffrey A Esq
# Bridgeport             Art     Venere            Chemel, James L Cpa
# Anchorage            Lenna   Paprocki         Feltz Printing Service
# Hamilton           Donette     Foller            Printing Dimensions
# Ashland             Simona    Morasca            Chapman, Ross E Esq
# Chicago             Mitsue    Tollner             Morlong Associates
# San Jose             Leota   Dilliard               Commercial Press
# Sioux Falls           Sage     Wieser      Truhlar And Truhlar Attys
# Baltimore             Kris    Marrier        King, Christopher A Esq
# Kulpsville           Minna     Amigon              Dorl, James J Esq
# Middle Island         Abel    Maclead            Rangoni Of Florence
# ...

# %%
data.loc["Brighton"]
# Out:
# first_name                          Josephine
# last_name                             Darakjy
# company_name            Chanay, Jeffrey A Esq
# address                   4 B Blue Ridge Blvd
# county                             Livingston
# state                                      MI
# zip                                     48116
# phone1                           810-292-9388
# phone                            810-374-9840
# email           josephine_darakjy@darakjy.org
# Name: Brighton, dtype: object

# %%
#extarct the information from 0 t0 9 index
data.loc["Brighton":"Sioux Falls"]
# Out:
#             first_name last_name               company_name  \
# city
# Brighton     Josephine   Darakjy      Chanay, Jeffrey A Esq
# Bridgeport         Art    Venere        Chemel, James L Cpa
# Anchorage        Lenna  Paprocki     Feltz Printing Service
# Hamilton       Donette    Foller        Printing Dimensions
# Ashland         Simona   Morasca        Chapman, Ross E Esq
# Chicago         Mitsue   Tollner         Morlong Associates
# San Jose         Leota  Dilliard           Commercial Press
# Sioux Falls       Sage    Wieser  Truhlar And Truhlar Attys
#
#                           address       county state    zip        phone1  \
# city
# Brighton      4 B Blue Ridge Blvd   Livingston    MI  48116  810-292-9388
# Bridgeport   8 W Cerritos Ave #54   Gloucester    NJ   8014  856-636-8749
# Anchorage             639 Main St    Anchorage    AK  99501  907-385-4412
# Hamilton             34 Center St       Butler    OH  45011  513-570-1893
# ...

# %%
data.loc[["Brighton","Sioux Falls"]]
# Out:
#             first_name last_name               company_name  \
# city
# Brighton     Josephine   Darakjy      Chanay, Jeffrey A Esq
# Sioux Falls       Sage    Wieser  Truhlar And Truhlar Attys
#
#                          address      county state    zip        phone1  \
# city
# Brighton     4 B Blue Ridge Blvd  Livingston    MI  48116  810-292-9388
# Sioux Falls     5 Boston Ave #88   Minnehaha    SD  57105  605-414-2147
#
#                     phone                          email
# city
# Brighton     810-374-9840  josephine_darakjy@darakjy.org
# Sioux Falls  605-794-4895            sage_wieser@cox.net

# %%
"Chicago" in data.index
# Out:
# True

# %%
#retrieve rows by index position
data = pd.read_csv("C:\\Users\\HP\\Downloads\\50-contacts.csv")

# %%
data.iloc[[15,20]]
# Out:
#    first_name last_name            company_name              address     city  \
# 15     Mattie  Poquette  Century Communications  73 State Road 434 E  Phoenix
# 20      Bette     Nicka            Sport En Art          6 S 33rd St    Aston
#
#       county state    zip        phone1         phone                email
# 15  Maricopa    AZ  85013  602-277-4385  602-953-6360       mattie@aol.com
# 20  Delaware    PA  19014  610-545-3615  610-492-4643  bette_nicka@cox.net

# %%
data.iloc[4:8]
# Out:
#   first_name last_name         company_name           address      city  \
# 4    Donette    Foller  Printing Dimensions      34 Center St  Hamilton
# 5     Simona   Morasca  Chapman, Ross E Esq      3 Mcauley Dr   Ashland
# 6     Mitsue   Tollner   Morlong Associates         7 Eads St   Chicago
# 7      Leota  Dilliard     Commercial Press  7 W Jackson Blvd  San Jose
#
#         county state    zip        phone1         phone  \
# 4       Butler    OH  45011  513-570-1893  513-549-4561
# 5      Ashland    OH  44805  419-503-2484  419-800-6759
# 6         Cook    IL  60632  773-573-6914  773-924-8565
# 7  Santa Clara    CA  95111  408-752-3500  408-813-1105
#
#                       email
# 4    donette.foller@cox.net
# 5        simona@morasca.com
# 6  mitsue_tollner@yahoo.com
# 7         leota@hotmail.com

# %%
#set new values
data = pd.read_csv("C:\\Users\\HP\\Downloads\\50-contacts.csv",index_col="county")
data
# Out:
#                      first_name  last_name                   company_name  \
# county
# Orleans                   James       Butt              Benton, John B Jr
# Livingston            Josephine    Darakjy          Chanay, Jeffrey A Esq
# Gloucester                  Art     Venere            Chemel, James L Cpa
# Anchorage                 Lenna   Paprocki         Feltz Printing Service
# Butler                  Donette     Foller            Printing Dimensions
# Ashland                  Simona    Morasca            Chapman, Ross E Esq
# Cook                     Mitsue    Tollner             Morlong Associates
# Santa Clara               Leota   Dilliard               Commercial Press
# Minnehaha                  Sage     Wieser      Truhlar And Truhlar Attys
# Baltimore City             Kris    Marrier        King, Christopher A Esq
# Montgomery                Minna     Amigon              Dorl, James J Esq
# Suffolk                    Abel    Maclead            Rangoni Of Florence
# ...

# %%
data.loc["Butler","city"] ="Karnataka"
data.loc["Butler"]
# Out:
# first_name                     Donette
# last_name                       Foller
# company_name       Printing Dimensions
# address                   34 Center St
# city                         Karnataka
# state                               OH
# zip                              45011
# phone1                    513-570-1893
# phone                     513-549-4561
# email           donette.foller@cox.net
# Name: Butler, dtype: object

# %%
data.loc["Butler",["phone","state","zip"]] = [42796426,"VL",677565]

# %%
data.loc["Butler"]
# Out:
# first_name                     Donette
# last_name                       Foller
# company_name       Printing Dimensions
# address                   34 Center St
# city                         Karnataka
# state                               VL
# zip                             677565
# phone1                    513-570-1893
# phone                         42796426
# email           donette.foller@cox.net
# Name: Butler, dtype: object

# %%
data1 = data["last_name"] =="Morasca"

# %%
data[data1]
# Out:
#         first_name last_name         company_name       address     city  \
# county
# Ashland     Simona   Morasca  Chapman, Ross E Esq  3 Mcauley Dr  Ashland
#
#         state    zip        phone1         phone               email
# county
# Ashland    OH  44805  419-503-2484  419-800-6759  simona@morasca.com

# %%
data.loc[data1,"last_name"]
# Out:
# county
# Ashland    Morasca
# Name: last_name, dtype: object

# %%
data.loc[data1,"last_name"] ="Docsta"

# %%
data
# Out:
#                      first_name  last_name                   company_name  \
# county
# Orleans                   James       Butt              Benton, John B Jr
# Livingston            Josephine    Darakjy          Chanay, Jeffrey A Esq
# Gloucester                  Art     Venere            Chemel, James L Cpa
# Anchorage                 Lenna   Paprocki         Feltz Printing Service
# Butler                  Donette     Foller            Printing Dimensions
# Ashland                  Simona     Docsta            Chapman, Ross E Esq
# Cook                     Mitsue    Tollner             Morlong Associates
# Santa Clara               Leota   Dilliard               Commercial Press
# Minnehaha                  Sage     Wieser      Truhlar And Truhlar Attys
# Baltimore City             Kris    Marrier        King, Christopher A Esq
# Montgomery                Minna     Amigon              Dorl, James J Esq
# Suffolk                    Abel    Maclead            Rangoni Of Florence
# ...

# %%
#Rename index Labels or coloumns
data.rename(mapper ={"Cook":"USA"})
# Out:
#                      first_name  last_name                   company_name  \
# county
# Orleans                   James       Butt              Benton, John B Jr
# Livingston            Josephine    Darakjy          Chanay, Jeffrey A Esq
# Gloucester                  Art     Venere            Chemel, James L Cpa
# Anchorage                 Lenna   Paprocki         Feltz Printing Service
# Butler                  Donette     Foller            Printing Dimensions
# Ashland                  Simona     Docsta            Chapman, Ross E Esq
# USA                      Mitsue    Tollner             Morlong Associates
# Santa Clara               Leota   Dilliard               Commercial Press
# Minnehaha                  Sage     Wieser      Truhlar And Truhlar Attys
# Baltimore City             Kris    Marrier        King, Christopher A Esq
# Montgomery                Minna     Amigon              Dorl, James J Esq
# Suffolk                    Abel    Maclead            Rangoni Of Florence
# ...

# %%
#columns
data.rename(mapper ={"address":"Location"},axis=1)
data.rename(mapper ={"address":"Location"},axis="columns")
# Out:
#                      first_name  last_name                   company_name  \
# county
# Orleans                   James       Butt              Benton, John B Jr
# Livingston            Josephine    Darakjy          Chanay, Jeffrey A Esq
# Gloucester                  Art     Venere            Chemel, James L Cpa
# Anchorage                 Lenna   Paprocki         Feltz Printing Service
# Butler                  Donette     Foller            Printing Dimensions
# Ashland                  Simona     Docsta            Chapman, Ross E Esq
# Cook                     Mitsue    Tollner             Morlong Associates
# Santa Clara               Leota   Dilliard               Commercial Press
# Minnehaha                  Sage     Wieser      Truhlar And Truhlar Attys
# Baltimore City             Kris    Marrier        King, Christopher A Esq
# Montgomery                Minna     Amigon              Dorl, James J Esq
# Suffolk                    Abel    Maclead            Rangoni Of Florence
# ...

# %%
data.columns=["first","last","name","pin","code","phone","phone1","fdf","phone1","gmail"]

# %%
data.head()
# Out:
#                 first      last                    name                   pin  \
# county
# Orleans         James      Butt       Benton, John B Jr    6649 N Blue Gum St
# Livingston  Josephine   Darakjy   Chanay, Jeffrey A Esq   4 B Blue Ridge Blvd
# Gloucester        Art    Venere     Chemel, James L Cpa  8 W Cerritos Ave #54
# Anchorage       Lenna  Paprocki  Feltz Printing Service           639 Main St
# Butler        Donette    Foller     Printing Dimensions          34 Center St
#
#                    code phone  phone1           fdf        phone1  \
# county
# Orleans     New Orleans    LA   70116  504-621-8927  504-845-1427
# Livingston     Brighton    MI   48116  810-292-9388  810-374-9840
# Gloucester   Bridgeport    NJ    8014  856-636-8749  856-264-4130
# Anchorage     Anchorage    AK   99501  907-385-4412  907-921-2010
# Butler        Karnataka    VL  677565  513-570-1893      42796426
#
#                                     gmail
# county
# ...

# %%
#delete rows and coloumns

data.drop("Orleans")
# Out:
#                           first       last                           name  \
# county
# Livingston            Josephine    Darakjy          Chanay, Jeffrey A Esq
# Gloucester                  Art     Venere            Chemel, James L Cpa
# Anchorage                 Lenna   Paprocki         Feltz Printing Service
# Butler                  Donette     Foller            Printing Dimensions
# Ashland                  Simona     Docsta            Chapman, Ross E Esq
# Cook                     Mitsue    Tollner             Morlong Associates
# Santa Clara               Leota   Dilliard               Commercial Press
# Minnehaha                  Sage     Wieser      Truhlar And Truhlar Attys
# Baltimore City             Kris    Marrier        King, Christopher A Esq
# Montgomery                Minna     Amigon              Dorl, James J Esq
# Suffolk                    Abel    Maclead            Rangoni Of Florence
# Los Angeles               Kiley  Caldarera                    Feiner Bros
# ...

# %%
data.drop("fdf",axis=1)
# Out:
#                           first       last                           name  \
# county
# Orleans                   James       Butt              Benton, John B Jr
# Livingston            Josephine    Darakjy          Chanay, Jeffrey A Esq
# Gloucester                  Art     Venere            Chemel, James L Cpa
# Anchorage                 Lenna   Paprocki         Feltz Printing Service
# Butler                  Donette     Foller            Printing Dimensions
# Ashland                  Simona     Docsta            Chapman, Ross E Esq
# Cook                     Mitsue    Tollner             Morlong Associates
# Santa Clara               Leota   Dilliard               Commercial Press
# Minnehaha                  Sage     Wieser      Truhlar And Truhlar Attys
# Baltimore City             Kris    Marrier        King, Christopher A Esq
# Montgomery                Minna     Amigon              Dorl, James J Esq
# Suffolk                    Abel    Maclead            Rangoni Of Florence
# ...

# %%
data.pop("pin")
# Out:
# county
# Orleans                    6649 N Blue Gum St
# Livingston                4 B Blue Ridge Blvd
# Gloucester               8 W Cerritos Ave #54
# Anchorage                         639 Main St
# Butler                           34 Center St
# Ashland                          3 Mcauley Dr
# Cook                                7 Eads St
# Santa Clara                  7 W Jackson Blvd
# Minnehaha                    5 Boston Ave #88
# Baltimore City          228 Runamuck Pl #2808
# Montgomery                   2371 Jerrold Ave
# Suffolk                    37275 St  Rt 17m M
# Los Angeles                  25 E 75th St #69
# Geauga                  98 Connecticut Ave Nw
# Webb                         56 E Morehead St
# Maricopa                  73 State Road 434 E
# Warren                    69734 E Carrillo St
# Milwaukee                322 New Horizon Blvd
# Wayne                        1 State Route 27
# Winnebago                 394 Manchester Blvd
# ...

# %%
del data["gmail"]

# %%
data
# Out:
#                           first       last                           name  \
# county
# Orleans                   James       Butt              Benton, John B Jr
# Livingston            Josephine    Darakjy          Chanay, Jeffrey A Esq
# Gloucester                  Art     Venere            Chemel, James L Cpa
# Anchorage                 Lenna   Paprocki         Feltz Printing Service
# Butler                  Donette     Foller            Printing Dimensions
# Ashland                  Simona     Docsta            Chapman, Ross E Esq
# Cook                     Mitsue    Tollner             Morlong Associates
# Santa Clara               Leota   Dilliard               Commercial Press
# Minnehaha                  Sage     Wieser      Truhlar And Truhlar Attys
# Baltimore City             Kris    Marrier        King, Christopher A Esq
# Montgomery                Minna     Amigon              Dorl, James J Esq
# Suffolk                    Abel    Maclead            Rangoni Of Florence
# ...

# %%
data = pd.read_csv("C:\\Users\\HP\\Downloads\\50-contacts.csv",index_col="county")

# %%
data.sort_values("zip",ascending =False)
# Out:
#                      first_name  last_name                   company_name  \
# county
# Fairbanks North Star      Erick    Ferencz        Cindy Turner Associates
# Fairbanks North Star     Roxane    Campain             Rapid Trading Intl
# Anchorage                 Lenna   Paprocki         Feltz Printing Service
# Crook                  Youlanda   Schemmer                 Tri M Tool Inc
# Santa Clara            Veronika     Inouye                C 4 Network Inc
# Santa Clara               Leota   Dilliard               Commercial Press
# Ventura                 Rozella   Ostrosky                Parkway Company
# Los Angeles               Kiley  Caldarera                    Feiner Bros
# Los Angeles             Kanisha    Waycott            Schroer, Gene E Esq
# Dona Ana               Francine    Vocelka    Cascade Realty Advisors Inc
# Maricopa                 Mattie   Poquette         Century Communications
# Bexar                 Valentine    Gillian           Fbs Business Finance
# ...

# %%
data.nlargest(4,columns="zip")
# Out:
#                      first_name last_name             company_name  \
# county
# Fairbanks North Star      Erick   Ferencz  Cindy Turner Associates
# Fairbanks North Star     Roxane   Campain       Rapid Trading Intl
# Anchorage                 Lenna  Paprocki   Feltz Printing Service
# Crook                  Youlanda  Schemmer           Tri M Tool Inc
#
#                               address        city state    zip        phone1  \
# county
# Fairbanks North Star  20 S Babcock St   Fairbanks    AK  99712  907-741-1044
# Fairbanks North Star     1048 Main St   Fairbanks    AK  99708  907-231-4722
# Anchorage                 639 Main St   Anchorage    AK  99501  907-385-4412
# Crook                   2881 Lewis Rd  Prineville    OR  97754  541-548-8197
#
#                              phone                  email
# county
# Fairbanks North Star  907-227-6777  erick.ferencz@aol.com
# Fairbanks North Star  907-335-6568     roxane@hotmail.com
# ...

# %%
data.nsmallest(4,columns="zip")
# Out:
#            first_name last_name          company_name               address  \
# county
# Suffolk          Jina  Briddick    Grace Pastries Inc       38938 Park Blvd
# Bergen          Ernie  Stenseth        Knwz Newsradio       45 E Liberty St
# Gloucester        Art    Venere   Chemel, James L Cpa  8 W Cerritos Ave #54
# Middlesex      Albina     Glick  Giampetro, Anthony D            4 Ralph Ct
#
#                        city state   zip        phone1         phone  \
# county
# Suffolk                 NaN    MA  2128  617-399-5124  617-997-5771
# Bergen      Ridgefield Park    NJ  7660  201-709-6245  201-387-9093
# Gloucester       Bridgeport    NJ  8014  856-636-8749  856-264-4130
# Middlesex          Dunellen    NJ  8812  732-924-7882  732-782-6701
#
#                                  email
# county
# Suffolk     jina_briddick@briddick.com
# Bergen          ernie_stenseth@aol.com
# Gloucester              art@venere.org
# Middlesex             albina@glick.com

# %%
data["zip"].nlargest(8)
# Out:
# county
# Fairbanks North Star    99712
# Fairbanks North Star    99708
# Anchorage               99501
# Crook                   97754
# Santa Clara             95111
# Santa Clara             95111
# Ventura                 93012
# Los Angeles             90034
# Name: zip, dtype: int64

# %%
data = pd.read_csv("C:\\Users\\HP\\Downloads\\50-contacts.csv",index_col="county")
data.head()
# Out:
#            first_name last_name            company_name               address  \
# county
# Orleans         James      Butt       Benton, John B Jr    6649 N Blue Gum St
# Livingston  Josephine   Darakjy   Chanay, Jeffrey A Esq   4 B Blue Ridge Blvd
# Gloucester        Art    Venere     Chemel, James L Cpa  8 W Cerritos Ave #54
# Anchorage       Lenna  Paprocki  Feltz Printing Service           639 Main St
# Butler        Donette    Foller     Printing Dimensions          34 Center St
#
#                    city state    zip        phone1         phone  \
# county
# Orleans     New Orleans    LA  70116  504-621-8927  504-845-1427
# Livingston     Brighton    MI  48116  810-292-9388  810-374-9840
# Gloucester   Bridgeport    NJ   8014  856-636-8749  856-264-4130
# Anchorage     Anchorage    AK  99501  907-385-4412  907-921-2010
# Butler         Hamilton    OH  45011  513-570-1893  513-549-4561
#
#                                     email
# county
# ...

# %%
mask = data["last_name"] =="Butt"

# %%
data.where(mask)
# Out:
#                      first_name last_name       company_name  \
# county
# Orleans                   James      Butt  Benton, John B Jr
# Livingston                  NaN       NaN                NaN
# Gloucester                  NaN       NaN                NaN
# Anchorage                   NaN       NaN                NaN
# Butler                      NaN       NaN                NaN
# Ashland                     NaN       NaN                NaN
# Cook                        NaN       NaN                NaN
# Santa Clara                 NaN       NaN                NaN
# Minnehaha                   NaN       NaN                NaN
# Baltimore City              NaN       NaN                NaN
# Montgomery                  NaN       NaN                NaN
# Suffolk                     NaN       NaN                NaN
# Los Angeles                 NaN       NaN                NaN
# Geauga                      NaN       NaN                NaN
# ...

# %%
data.columns =[column_name.replace(" ","_")for column_name in data.columns]

# %%
data
# Out:
#                      first_name  last_name                   company_name  \
# county
# Orleans                   James       Butt              Benton, John B Jr
# Livingston            Josephine    Darakjy          Chanay, Jeffrey A Esq
# Gloucester                  Art     Venere            Chemel, James L Cpa
# Anchorage                 Lenna   Paprocki         Feltz Printing Service
# Butler                  Donette     Foller            Printing Dimensions
# Ashland                  Simona    Morasca            Chapman, Ross E Esq
# Cook                     Mitsue    Tollner             Morlong Associates
# Santa Clara               Leota   Dilliard               Commercial Press
# Minnehaha                  Sage     Wieser      Truhlar And Truhlar Attys
# Baltimore City             Kris    Marrier        King, Christopher A Esq
# Montgomery                Minna     Amigon              Dorl, James J Esq
# Suffolk                    Abel    Maclead            Rangoni Of Florence
# ...

# %%
data.query('city=="New Orleans"')
# Out:
#         first_name last_name       company_name             address  \
# county
# Orleans      James      Butt  Benton, John B Jr  6649 N Blue Gum St
#
#                 city state    zip        phone1         phone            email
# county
# Orleans  New Orleans    LA  70116  504-621-8927  504-845-1427  jbutt@gmail.com

# %%
data.query('city=="New Orleans" and state =="LA"')
# Out:
#         first_name last_name       company_name             address  \
# county
# Orleans      James      Butt  Benton, John B Jr  6649 N Blue Gum St
#
#                 city state    zip        phone1         phone            email
# county
# Orleans  New Orleans    LA  70116  504-621-8927  504-845-1427  jbutt@gmail.com

# %%
def convert(number):
    return str(number)+"millions"
data["zip"] = data["zip"].apply(convert)

# %%
data["zip"]
# Out:
# county
# Orleans                 70116millions
# Livingston              48116millions
# Gloucester               8014millions
# Anchorage               99501millions
# Butler                  45011millions
# Ashland                 44805millions
# Cook                    60632millions
# Santa Clara             95111millions
# Minnehaha               57105millions
# Baltimore City          21224millions
# Montgomery              19443millions
# Suffolk                 11953millions
# Los Angeles             90034millions
# Geauga                  44023millions
# Webb                    78045millions
# Maricopa                85013millions
# Warren                  37110millions
# Milwaukee               53207millions
# Wayne                   48180millions
# Winnebago               61109millions
# Delaware                19014millions
# Santa Clara             95111millions
# Dallas                  75062millions
# Albany                  12204millions
# ...

# %%
columns =["zip","email","address"]
for col in columns:
    data[col] = data[col].apply(convert)

# %%
data.head()
# Out:
#            first_name last_name            company_name  \
# county
# Orleans         James      Butt       Benton, John B Jr
# Livingston  Josephine   Darakjy   Chanay, Jeffrey A Esq
# Gloucester        Art    Venere     Chemel, James L Cpa
# Anchorage       Lenna  Paprocki  Feltz Printing Service
# Butler        Donette    Foller     Printing Dimensions
#
#                                  address         city state  \
# county
# Orleans       6649 N Blue Gum Stmillions  New Orleans    LA
# Livingston   4 B Blue Ridge Blvdmillions     Brighton    MI
# Gloucester  8 W Cerritos Ave #54millions   Bridgeport    NJ
# Anchorage            639 Main Stmillions    Anchorage    AK
# Butler              34 Center Stmillions     Hamilton    OH
#
#                               zip        phone1         phone  \
# county
# Orleans     70116millionsmillions  504-621-8927  504-845-1427
# Livingston  48116millionsmillions  810-292-9388  810-374-9840
# ...

# %%
#copy method

zip1 = data["zip"]
zip1.head(3)
# Out:
# county
# Orleans       70116millionsmillions
# Livingston    48116millionsmillions
# Gloucester     8014millionsmillions
# Name: zip, dtype: object

# %%
data1 = data["zip"].copy()

# %%
data1.head(3)
# Out:
# county
# Orleans       70116millionsmillions
# Livingston    48116millionsmillions
# Gloucester     8014millionsmillions
# Name: zip, dtype: object

# %%
data1["Orleans"] ="Karnataka"

# %%
data1.head()
# Out:
# county
# Orleans                   Karnataka
# Livingston    48116millionsmillions
# Gloucester     8014millionsmillions
# Anchorage     99501millionsmillions
# Butler        45011millionsmillions
# Name: zip, dtype: object

# %%
data.head()
# Out:
#            first_name last_name            company_name  \
# county
# Orleans         James      Butt       Benton, John B Jr
# Livingston  Josephine   Darakjy   Chanay, Jeffrey A Esq
# Gloucester        Art    Venere     Chemel, James L Cpa
# Anchorage       Lenna  Paprocki  Feltz Printing Service
# Butler        Donette    Foller     Printing Dimensions
#
#                                  address         city state  \
# county
# Orleans       6649 N Blue Gum Stmillions  New Orleans    LA
# Livingston   4 B Blue Ridge Blvdmillions     Brighton    MI
# Gloucester  8 W Cerritos Ave #54millions   Bridgeport    NJ
# Anchorage            639 Main Stmillions    Anchorage    AK
# Butler              34 Center Stmillions     Hamilton    OH
#
#                               zip        phone1         phone  \
# county
# Orleans     70116millionsmillions  504-621-8927  504-845-1427
# Livingston  48116millionsmillions  810-292-9388  810-374-9840
# ...
